# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm.auto import tqdm

from src.configspace import (
    COX_PH_CONFIGSPACE,
    GB_COX_CONFIGSPACE,
    GPR_CONFIGSPACE,
    POLY_RIDGE_CONFIGSPACE,
    RANDOM_FOREST_CONFIGSPACE,
    RANDOM_SURVIVAL_FOREST_CONFIGSPACE,
    RIDGE_CONFIGSPACE,
    SCHMEE_HAHN_QRF_CONFIGSPACE,
    SVR_CONFIGSPACE,
    TOBIT_NN_CONFIGSPACE,
    XGB_AFT_CONFIGSPACE,
    XGB_CONFIGSPACE,
)
from src.constant import (
    HO,
    PROCESSED_DATA_DIR,
    RANDOM_STATE_LIST,
    RESULTS_PERMUTATION_DIR,
    SOLVER_NUMBER_LIST,
)
from src.evaluation import evaluate_model_with_cross_validation
from src.hyperparameter_optimization import optimize_hyperparameters
from src.model import (
    SVR,
    CoxPHSurvivalAnalysis,
    GPRWithRBF,
    GradientBoostingSurvivalAnalysis,
    PolynomialRidge,
    RandomForestRegressor,
    RandomSurvivalForest,
    Ridge,
    SchmeeHahnQRF,
    TobitModel,
    XGBRegressor,
    XGBRegressorAFT,
)
from src.results import plot_line, plot_scatter, wilcoxon_df
from src.split import get_n_splits
from src.wrapper import (
    ScikitLearnWrapper,
    SkipCutOffScikitLearnWrapper,
    StandardScaledLogTransformedWrapper,
    SurvivalFunctionWrapper,
    XGBwrapper,
)

# %%
evaluations_df = pd.read_parquet(PROCESSED_DATA_DIR / "evaluations.parquet")
solvers_df = pd.read_parquet(PROCESSED_DATA_DIR / "solvers.parquet")
instances_df = pd.read_parquet(PROCESSED_DATA_DIR / "instances.parquet")

df = pd.merge(evaluations_df, solvers_df, left_on="solver_id", right_on="id").drop(columns=["id"])
df = pd.merge(df, instances_df, left_on="instance_id", right_on="id").drop(columns=["id"])
df
# Out:
#                  solver_id                       instance_id       generator  \
# 0      1251473931473582278  TSP/TRAIN/cluster_netgen/000.tsp  cluster_netgen
# 1      2289112522627003788  TSP/TRAIN/cluster_netgen/000.tsp  cluster_netgen
# 2       960932965817811220  TSP/TRAIN/cluster_netgen/000.tsp  cluster_netgen
# 3        39012066323493184  TSP/TRAIN/cluster_netgen/000.tsp  cluster_netgen
# 4       494182449327999052  TSP/TRAIN/cluster_netgen/000.tsp  cluster_netgen
# ...                    ...                               ...             ...
# 99995  1286196444435323941            TSP/TRAIN/grid/019.tsp            grid
# 99996  1435531534300921454            TSP/TRAIN/grid/019.tsp            grid
# 99997    27607668447685341            TSP/TRAIN/grid/019.tsp            grid
# 99998  2245205590089179674            TSP/TRAIN/grid/019.tsp            grid
# 99999    85558984741464718            TSP/TRAIN/grid/019.tsp            grid
#
#          cost  ASCENT_CANDIDATES  BACKBONE_TRIALS  BACKTRACKING  \
# 0        4.74               0.95              1.0           0.0
# 1        0.02               0.15              0.0           1.0
# 2        3.72               0.20              0.0           1.0
# 3        1.52               0.60              1.0           1.0
# 4       84.44               0.90              1.0           1.0
# ...       ...                ...              ...           ...
# 99995  208.32               0.45              0.0           0.0
# 99996  300.00               0.20              1.0           0.0
# 99997    3.21               0.95              1.0           1.0
# 99998   17.23               0.65              0.0           0.0
# 99999    0.01               0.90              1.0           0.0
#
#        CANDIDATE_SET_TYPE  EXTRA_CANDIDATES  EXTRA_CANDIDATE_SET_TYPE  ...  \
# 0                     0.0               0.2                       0.0  ...
# 1                     1.0               0.4                       0.0  ...
# 2                     2.0               0.9                       0.0  ...
# 3                     2.0               0.7                       0.0  ...
# 4                     3.0               0.3                       0.0  ...
# ...                   ...               ...                       ...  ...
# 99995                 0.0               0.2                       0.0  ...
# 99996                 3.0               0.6                       0.0  ...
# 99997                 3.0               0.9                       0.0  ...
# 99998                 1.0               0.5                       0.0  ...
# 99999                 3.0               0.6                       0.0  ...
#
#        mst_dists_span  mst_dists_coef_of_var  mst_dists_sum  nnds_min  \
# 0            0.488488               1.790135       0.000225  0.000715
# 1            0.488488               1.790135       0.000225  0.000715
# 2            0.488488               1.790135       0.000225  0.000715
# 3            0.488488               1.790135       0.000225  0.000715
# 4            0.488488               1.790135       0.000225  0.000715
# ...               ...                    ...            ...       ...
# 99995        0.093952               0.462330       0.000294  0.001335
# 99996        0.093952               0.462330       0.000294  0.001335
# 99997        0.093952               0.462330       0.000294  0.001335
# 99998        0.093952               0.462330       0.000294  0.001335
# 99999        0.093952               0.462330       0.000294  0.001335
#
#        nnds_median  nnds_mean  nnds_max   nnds_sd  nnds_span  nnds_coef_of_var
# 0         0.011143   0.014421  0.094965  0.012746   0.094250          0.883825
# 1         0.011143   0.014421  0.094965  0.012746   0.094250          0.883825
# 2         0.011143   0.014421  0.094965  0.012746   0.094250          0.883825
# 3         0.011143   0.014421  0.094965  0.012746   0.094250          0.883825
# 4         0.011143   0.014421  0.094965  0.012746   0.094250          0.883825
# ...            ...        ...       ...       ...        ...               ...
# 99995     0.029728   0.032519  0.095287  0.017339   0.093952          0.533201
# 99996     0.029728   0.032519  0.095287  0.017339   0.093952          0.533201
# 99997     0.029728   0.032519  0.095287  0.017339   0.093952          0.533201
# 99998     0.029728   0.032519  0.095287  0.017339   0.093952          0.533201
# 99999     0.029728   0.032519  0.095287  0.017339   0.093952          0.533201
#
# [100000 rows x 91 columns]

# %%
PERMUATION_LOGNORMAL_MEAN_SIGMA = (0, 1)

# %%
SPLITS = get_n_splits(
    df=df,
    n=HO.N,
    instance_number=HO.INSTANCE_NUMBER,
    solver_number=HO.SOLVER_NUMBER,
    random_state=HO.RANDOM_STATE,
)

# %% [markdown]
# ### Ridge

# %%
ridge_incumbent = optimize_hyperparameters(
    df=df,
    model_cls=Ridge,
    wrapper_cls=ScikitLearnWrapper,
    configspace=RIDGE_CONFIGSPACE,
    splits=SPLITS,
    permuation_lognormal_mean_sigma=PERMUATION_LOGNORMAL_MEAN_SIGMA,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_PERMUTATION_DIR / "HO" / "ridge_incumbent.pkl",
)

ridge_incumbent_skip_cutoff = optimize_hyperparameters(
    df=df,
    model_cls=Ridge,
    wrapper_cls=SkipCutOffScikitLearnWrapper,
    configspace=RIDGE_CONFIGSPACE,
    splits=SPLITS,
    permuation_lognormal_mean_sigma=PERMUATION_LOGNORMAL_MEAN_SIGMA,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_PERMUTATION_DIR / "HO" / "ridge_incumbent_skip_cutoff.pkl",
)

# %% [markdown]
# ### PolynomialRidge

# %%
poly_ridge_incumbent = optimize_hyperparameters(
    df=df,
    model_cls=PolynomialRidge,
    wrapper_cls=ScikitLearnWrapper,
    configspace=POLY_RIDGE_CONFIGSPACE,
    splits=SPLITS,
    permuation_lognormal_mean_sigma=PERMUATION_LOGNORMAL_MEAN_SIGMA,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_PERMUTATION_DIR / "HO" / "poly_ridge_incumbent.pkl",
)

poly_ridge_incumbent_skip_cutoff = optimize_hyperparameters(
    df=df,
    model_cls=PolynomialRidge,
    wrapper_cls=SkipCutOffScikitLearnWrapper,
    configspace=POLY_RIDGE_CONFIGSPACE,
    splits=SPLITS,
    permuation_lognormal_mean_sigma=PERMUATION_LOGNORMAL_MEAN_SIGMA,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_PERMUTATION_DIR / "HO" / "poly_ridge_incumbent_skip_cutoff.pkl",
)

# %% [markdown]
# ### RandomForestRegressor

# %%
rf_incumbent = optimize_hyperparameters(
    df=df,
    model_cls=RandomForestRegressor,
    wrapper_cls=ScikitLearnWrapper,
    configspace=RANDOM_FOREST_CONFIGSPACE,
    splits=SPLITS,
    permuation_lognormal_mean_sigma=PERMUATION_LOGNORMAL_MEAN_SIGMA,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_PERMUTATION_DIR / "HO" / "rf_incumbent.pkl",
)

rf_incumbent_skip_cutoff = optimize_hyperparameters(
    df=df,
    model_cls=RandomForestRegressor,
    wrapper_cls=SkipCutOffScikitLearnWrapper,
    configspace=RANDOM_FOREST_CONFIGSPACE,
    splits=SPLITS,
    permuation_lognormal_mean_sigma=PERMUATION_LOGNORMAL_MEAN_SIGMA,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_PERMUTATION_DIR / "HO" / "rf_incumbent_skip_cutoff.pkl",
)

# %% [markdown]
# ### XGBRegressor

# %%
xgb_incumbent = optimize_hyperparameters(
    df=df,
    model_cls=XGBRegressor,
    wrapper_cls=ScikitLearnWrapper,
    configspace=XGB_CONFIGSPACE,
    splits=SPLITS,
    permuation_lognormal_mean_sigma=PERMUATION_LOGNORMAL_MEAN_SIGMA,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_PERMUTATION_DIR / "HO" / "xgb_incumbent.pkl",
)

xgb_incumbent_skip_cutoff = optimize_hyperparameters(
    df=df,
    model_cls=XGBRegressor,
    wrapper_cls=SkipCutOffScikitLearnWrapper,
    configspace=XGB_CONFIGSPACE,
    splits=SPLITS,
    permuation_lognormal_mean_sigma=PERMUATION_LOGNORMAL_MEAN_SIGMA,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_PERMUTATION_DIR / "HO" / "xgb_incumbent_skip_cutoff.pkl",
)

# %% [markdown]
# ### SVR

# %%
svr_incumbent = optimize_hyperparameters(
    df=df,
    model_cls=SVR,
    wrapper_cls=ScikitLearnWrapper,
    configspace=SVR_CONFIGSPACE,
    splits=SPLITS,
    permuation_lognormal_mean_sigma=PERMUATION_LOGNORMAL_MEAN_SIGMA,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_PERMUTATION_DIR / "HO" / "svr_incumbent.pkl",
)

svr_incumbent_skip_cutoff = optimize_hyperparameters(
    df=df,
    model_cls=SVR,
    wrapper_cls=SkipCutOffScikitLearnWrapper,
    configspace=SVR_CONFIGSPACE,
    splits=SPLITS,
    permuation_lognormal_mean_sigma=PERMUATION_LOGNORMAL_MEAN_SIGMA,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_PERMUTATION_DIR / "HO" / "svr_incumbent_skip_cutoff.pkl",
)

# %% [markdown]
# ### GPRWithRBF

# %%
gpr_incumbent = optimize_hyperparameters(
    df=df,
    model_cls=GPRWithRBF,
    wrapper_cls=ScikitLearnWrapper,
    configspace=GPR_CONFIGSPACE,
    splits=SPLITS,
    permuation_lognormal_mean_sigma=PERMUATION_LOGNORMAL_MEAN_SIGMA,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_PERMUTATION_DIR / "HO" / "gpr_incumbent.pkl",
)

gpr_incumbent_skip_cutoff = optimize_hyperparameters(
    df=df,
    model_cls=GPRWithRBF,
    wrapper_cls=SkipCutOffScikitLearnWrapper,
    configspace=GPR_CONFIGSPACE,
    splits=SPLITS,
    permuation_lognormal_mean_sigma=PERMUATION_LOGNORMAL_MEAN_SIGMA,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_PERMUTATION_DIR / "HO" / "gpr_incumbent_skip_cutoff.pkl",
)

# %% [markdown]
# ### CoxPHSurvivalAnalysis

# %%
coxph_incumbent = optimize_hyperparameters(
    df=df,
    model_cls=CoxPHSurvivalAnalysis,
    wrapper_cls=SurvivalFunctionWrapper,
    configspace=COX_PH_CONFIGSPACE,
    splits=SPLITS,
    permuation_lognormal_mean_sigma=PERMUATION_LOGNORMAL_MEAN_SIGMA,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_PERMUTATION_DIR / "HO" / "coxph_incumbent.pkl",
)
coxph_incumbent
# Out:
# {'alpha': 13.6880493422333,
#  'risk_function': 'polynomial',
#  'ties': 'breslow',
#  'risk_alpha': 0.553369716052,
#  'model_cls': sksurv.linear_model.coxph.CoxPHSurvivalAnalysis}

# %% [markdown]
# ### RandomSurvivalForest

# %%
rsf_incumbent = optimize_hyperparameters(
    df=df,
    model_cls=RandomSurvivalForest,
    wrapper_cls=SurvivalFunctionWrapper,
    configspace=RANDOM_SURVIVAL_FOREST_CONFIGSPACE,
    splits=SPLITS,
    permuation_lognormal_mean_sigma=PERMUATION_LOGNORMAL_MEAN_SIGMA,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_PERMUTATION_DIR / "HO" / "rsf_incumbent.pkl",
)
rsf_incumbent
# Out:
# {'max_depth': 7,
#  'max_features': 0.949975513741,
#  'min_samples_leaf': 8,
#  'min_samples_split': 2,
#  'n_jobs': -1,
#  'random_state': 0,
#  'risk_function': 'exponential',
#  'risk_alpha': 1.718875737677,
#  'risk_beta': 11.7850369367298,
#  'model_cls': sksurv.ensemble.forest.RandomSurvivalForest}

# %% [markdown]
# ### GradientBoostingSurvivalAnalysis

# %%
gb_cox_incumbent = optimize_hyperparameters(
    df=df,
    model_cls=GradientBoostingSurvivalAnalysis,
    wrapper_cls=SurvivalFunctionWrapper,
    configspace=GB_COX_CONFIGSPACE,
    splits=SPLITS,
    permuation_lognormal_mean_sigma=PERMUATION_LOGNORMAL_MEAN_SIGMA,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_PERMUTATION_DIR / "HO" / "gb_cox_incumbent.pkl",
)
gb_cox_incumbent
# Out:
# {'ccp_alpha': 0.0023850197557,
#  'learning_rate': 0.2319669631084,
#  'loss': 'coxph',
#  'max_depth': 5,
#  'max_features': 0.7194957289126,
#  'min_samples_leaf': 32,
#  'min_samples_split': 5,
#  'n_estimators': 472,
#  'random_state': 0,
#  'risk_function': 'polynomial',
#  'subsample': 0.6286117496721,
#  'risk_alpha': 0.8009472438586,
#  'model_cls': sksurv.ensemble.boosting.GradientBoostingSurvivalAnalysis}

# %% [markdown]
# ### XGBRegressorAFT

# %%
xgb_aft_incumbent = optimize_hyperparameters(
    df=df,
    model_cls=XGBRegressorAFT,
    wrapper_cls=XGBwrapper,
    configspace=XGB_AFT_CONFIGSPACE,
    splits=SPLITS,
    permuation_lognormal_mean_sigma=PERMUATION_LOGNORMAL_MEAN_SIGMA,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_PERMUTATION_DIR / "HO" / "xgb_aft_incumbent.pkl",
)
xgb_aft_incumbent
# Out:
# {'aft_loss_distribution': 'logistic',
#  'colsample_bytree': 0.6298013597726,
#  'eval_metric': 'aft-nloglik',
#  'gamma': 2.5000043394916,
#  'learning_rate': 0.0732260708093,
#  'max_depth': 3,
#  'min_child_weight': 5,
#  'num_boost_round': 627,
#  'objective': 'survival:aft',
#  'reg_alpha': 0.0059666994075,
#  'reg_lambda': 0.0012793868001,
#  'seed': 0,
#  'subsample': 0.5567903424362,
#  'aft_loss_distribution_scale': 0.7159987670782,
#  'model_cls': src.model.XGBRegressorAFT}

# %% [markdown]
# ### SchmeeHahnQRF

# %%
sh_qrf_incumbent = optimize_hyperparameters(
    df=df,
    model_cls=SchmeeHahnQRF,
    wrapper_cls=StandardScaledLogTransformedWrapper,
    configspace=SCHMEE_HAHN_QRF_CONFIGSPACE,
    splits=SPLITS,
    permuation_lognormal_mean_sigma=PERMUATION_LOGNORMAL_MEAN_SIGMA,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_PERMUTATION_DIR / "HO" / "sh_qrf_incumbent.pkl",
)
sh_qrf_incumbent
# Out:
# {'ccp_alpha': 9.8914673891022,
#  'ccp_alpha_rf': 0.0041071537615,
#  'k': 9,
#  'max_depth': 5,
#  'max_depth_rf': 10,
#  'max_features': 0.3337949284601,
#  'max_features_rf': 0.7497599367464,
#  'min_samples_leaf': 23,
#  'min_samples_leaf_rf': 2,
#  'min_samples_split': 14,
#  'min_samples_split_rf': 2,
#  'n_jobs': -1,
#  'random_state': 0,
#  'model_cls': src.model.SchmeeHahnQRF}

# %% [markdown]
# ### TobitModel

# %%
tobit_incumbent = optimize_hyperparameters(
    df=df,
    model_cls=TobitModel,
    wrapper_cls=StandardScaledLogTransformedWrapper,
    configspace=TOBIT_NN_CONFIGSPACE,
    splits=SPLITS,
    permuation_lognormal_mean_sigma=PERMUATION_LOGNORMAL_MEAN_SIGMA,
    random_state=HO.RANDOM_STATE,
    n_trials=HO.N_TRIALS,
    filepath=RESULTS_PERMUTATION_DIR / "HO" / "tobit_incumbent.pkl",
)
tobit_incumbent
# Out:
# {'base_lr': 0.000165734273,
#  'dropout': 0.3203885259132,
#  'momentum': 0.3836434474096,
#  'n_epochs': 161,
#  'scheduler_step_size_up': 690,
#  'model_cls': src.model.TobitModel}

# %% [markdown]
# ## Comparison

# %%
model_info_list = [
    # include cut-off
    {
        "wrapper": ScikitLearnWrapper(**ridge_incumbent),
        "name": "Ridge Regression"
    },
    {
        "wrapper": ScikitLearnWrapper(**poly_ridge_incumbent),
        "name": "Polynomial Regression"
    },
    {
        "wrapper": ScikitLearnWrapper(**svr_incumbent),
        "name": "Support Vector Regression"
    },
    {
        "wrapper": ScikitLearnWrapper(**gpr_incumbent),
        "name": "Gaussian Process Regression"
    },
    {
        "wrapper": ScikitLearnWrapper(**rf_incumbent),
        "name": "Random Forest"
    },
    {
        "wrapper": ScikitLearnWrapper(**xgb_incumbent),
        "name": "XGBoost"
    },
    # skip cut-off
    {
        "wrapper": SkipCutOffScikitLearnWrapper(**ridge_incumbent_skip_cutoff),
        "name": "Ridge Regression (skip cut-off)"
    },
    {
        "wrapper": SkipCutOffScikitLearnWrapper(**poly_ridge_incumbent_skip_cutoff),
        "name": "Polynomial Regression (skip cut-off)"
    },
    {
        "wrapper": SkipCutOffScikitLearnWrapper(**svr_incumbent_skip_cutoff),
        "name": "Support Vector Regression (skip cut-off)"
    },
    {
        "wrapper": SkipCutOffScikitLearnWrapper(**gpr_incumbent_skip_cutoff),
        "name": "Gaussian Process Regression (skip cut-off)"
    },
    {
        "wrapper": SkipCutOffScikitLearnWrapper(**rf_incumbent_skip_cutoff),
        "name": "Random Forest (skip cut-off)"
    },
    {
        "wrapper": SkipCutOffScikitLearnWrapper(**xgb_incumbent_skip_cutoff),
        "name": "XGBoost (skip cut-off)"
    },
    # survival models
    {
        "wrapper": SurvivalFunctionWrapper(**coxph_incumbent),
        "name": "Cox PH"
    },
    {
        "wrapper": SurvivalFunctionWrapper(**rsf_incumbent),
        "name": "Random Survival Forest"
    },
    {
        "wrapper": SurvivalFunctionWrapper(**gb_cox_incumbent),
        "name": "Gradient Boosting Cox"
    },
    {
        "wrapper": XGBwrapper(**xgb_aft_incumbent),
        "name": "XGBoost AFT"
    },
    {
        "wrapper": StandardScaledLogTransformedWrapper(**sh_qrf_incumbent),
        "name": "S&H QRF"
    },
    {
        "wrapper": StandardScaledLogTransformedWrapper(**tobit_incumbent),
        "name": "NN Tobit"
    },
]
 
# total_iterations = len(RANDOM_STATE_LIST) * len(SOLVER_NUMBER_LIST) * len(model_info_list)
# pbar = tqdm(total=total_iterations, desc="Evaluating models")

# records = []

# for random_state in RANDOM_STATE_LIST:
#     for solver_number in SOLVER_NUMBER_LIST:
#         pbar.set_description(f"RS={random_state}, Solvers={solver_number}")
#         splits = get_n_splits(
#             df,
#             n=5,
#             instance_number=10,
#             solver_number=solver_number,
#             random_state=random_state,
#         )
#         for model_info in model_info_list:
#             pbar.set_postfix(model=model_info["name"])

#             result = evaluate_model_with_cross_validation(
#                 df,
#                 wrapper=model_info["wrapper"],
#                 splits=splits,
#                 random_state=random_state,
#                 permuation_lognormal_mean_sigma=PERMUATION_LOGNORMAL_MEAN_SIGMA,
#             )
#             result["random_state"] = random_state
#             result["solver_number"] = solver_number
#             result["name"] = model_info["name"]
#             records.append(result)
#             pbar.update(1)

# pbar.close()
# result_df = pd.DataFrame(records)
# result_df.to_pickle(RESULTS_PERMUTATION_DIR / "results.gzip", compression="gzip")

result_df = pd.read_pickle(RESULTS_PERMUTATION_DIR / "results.gzip", compression="gzip")

# %%
fig, ax = plot_line(
    result_df.loc[
        result_df["name"].isin(
            [
                "Cox PH",
                "Random Survival Forest",
                "Gradient Boosting Cox",
                "XGBoost AFT",
                "S&H QRF",
                "NN Tobit",
            ]
        )
    ]
)

plt.savefig("fig.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
styled_result = wilcoxon_df(result_df, model_info_list)
styled_result
# Out:
# <style type="text/css">
# #T_09d32_row0_col0, #T_09d32_row0_col1, #T_09d32_row0_col2, #T_09d32_row1_col0, #T_09d32_row1_col1, #T_09d32_row2_col0, #T_09d32_row2_col1, #T_09d32_row2_col3, #T_09d32_row3_col2, #T_09d32_row3_col3, #T_09d32_row4_col0, #T_09d32_row4_col1, #T_09d32_row4_col3, #T_09d32_row5_col0, #T_09d32_row5_col1, #T_09d32_row5_col3, #T_09d32_row6_col0, #T_09d32_row7_col0, #T_09d32_row8_col0, #T_09d32_row9_col0, #T_09d32_row10_col0, #T_09d32_row10_col1, #T_09d32_row11_col0, #T_09d32_row11_col1, #T_09d32_row12_col0, #T_09d32_row12_col1, #T_09d32_row12_col3, #T_09d32_row12_col4, #T_09d32_row13_col0, #T_09d32_row13_col3, #T_09d32_row14_col1, #T_09d32_row14_col2, #T_09d32_row14_col3, #T_09d32_row14_col6, #T_09d32_row14_col7, #T_09d32_row15_col1, #T_09d32_row15_col2, #T_09d32_row15_col4, #T_09d32_row15_col5, #T_09d32_row16_col0, #T_09d32_row16_col1, #T_09d32_row16_col3, #T_09d32_row16_col4, #T_09d32_row16_col5, #T_09d32_row17_col2 {
#   font-weight: bold;
# }
# #T_09d32_row3_col0, #T_09d32_row3_col1, #T_09d32_row12_col2, #T_09d32_row14_col4, #T_09d32_row14_col5, #T_09d32_row15_col3, #T_09d32_row15_col6, #T_09d32_row15_col7, #T_09d32_row15_col8, #T_09d32_row15_col9, #T_09d32_row15_col10, #T_09d32_row15_col11 {
#   font-weight: bold;
#   background-color: yellow;
# }
# </style>
# <table id="T_09d32">
#   <thead>
#     <tr>
#       <th class="index_name level0" >solver_number</th>
#       <th id="T_09d32_level0_col0" class="col_heading level0 col0" >5</th>
#       <th id="T_09d32_level0_col1" class="col_heading level0 col1" >10</th>
#       <th id="T_09d32_level0_col2" class="col_heading level0 col2" >15</th>
#       <th id="T_09d32_level0_col3" class="col_heading level0 col3" >20</th>
#       <th id="T_09d32_level0_col4" class="col_heading level0 col4" >30</th>
#       <th id="T_09d32_level0_col5" class="col_heading level0 col5" >50</th>
#       <th id="T_09d32_level0_col6" class="col_heading level0 col6" >70</th>
#       <th id="T_09d32_level0_col7" class="col_heading level0 col7" >100</th>
#       <th id="T_09d32_level0_col8" class="col_heading level0 col8" >150</th>
#       <th id="T_09d32_level0_col9" class="col_heading level0 col9" >200</th>
#       <th id="T_09d32_level0_col10" class="col_heading level0 col10" >300</th>
#       <th id="T_09d32_level0_col11" class="col_heading level0 col11" >500</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09d32_level0_row0" class="row_heading level0 row0" >Ridge Regression</th>
#       <td id="T_09d32_row0_col0" class="data row0 col0" >2.960</td>
#       <td id="T_09d32_row0_col1" class="data row0 col1" >2.777</td>
#       <td id="T_09d32_row0_col2" class="data row0 col2" >2.764</td>
#       <td id="T_09d32_row0_col3" class="data row0 col3" >2.945</td>
#       <td id="T_09d32_row0_col4" class="data row0 col4" >3.259</td>
#       <td id="T_09d32_row0_col5" class="data row0 col5" >2.849</td>
#       <td id="T_09d32_row0_col6" class="data row0 col6" >2.814</td>
#       <td id="T_09d32_row0_col7" class="data row0 col7" >2.814</td>
#       <td id="T_09d32_row0_col8" class="data row0 col8" >2.858</td>
#       <td id="T_09d32_row0_col9" class="data row0 col9" >2.913</td>
#       <td id="T_09d32_row0_col10" class="data row0 col10" >3.043</td>
#       <td id="T_09d32_row0_col11" class="data row0 col11" >3.069</td>
#     </tr>
#     <tr>
#       <th id="T_09d32_level0_row1" class="row_heading level0 row1" >Polynomial Regression</th>
#       <td id="T_09d32_row1_col0" class="data row1 col0" >2.982</td>
#       <td id="T_09d32_row1_col1" class="data row1 col1" >2.765</td>
#       <td id="T_09d32_row1_col2" class="data row1 col2" >2.830</td>
#       <td id="T_09d32_row1_col3" class="data row1 col3" >2.840</td>
#       <td id="T_09d32_row1_col4" class="data row1 col4" >2.963</td>
#       <td id="T_09d32_row1_col5" class="data row1 col5" >3.002</td>
#       <td id="T_09d32_row1_col6" class="data row1 col6" >3.020</td>
#       <td id="T_09d32_row1_col7" class="data row1 col7" >3.077</td>
#       <td id="T_09d32_row1_col8" class="data row1 col8" >3.080</td>
#       <td id="T_09d32_row1_col9" class="data row1 col9" >3.099</td>
#       <td id="T_09d32_row1_col10" class="data row1 col10" >3.135</td>
#       <td id="T_09d32_row1_col11" class="data row1 col11" >3.083</td>
#     </tr>
#     <tr>
#       <th id="T_09d32_level0_row2" class="row_heading level0 row2" >Support Vector Regression</th>
#       <td id="T_09d32_row2_col0" class="data row2 col0" >2.904</td>
#       <td id="T_09d32_row2_col1" class="data row2 col1" >2.708</td>
#       <td id="T_09d32_row2_col2" class="data row2 col2" >2.708</td>
#       <td id="T_09d32_row2_col3" class="data row2 col3" >2.683</td>
#       <td id="T_09d32_row2_col4" class="data row2 col4" >2.801</td>
#       <td id="T_09d32_row2_col5" class="data row2 col5" >2.846</td>
#       <td id="T_09d32_row2_col6" class="data row2 col6" >2.829</td>
#       <td id="T_09d32_row2_col7" class="data row2 col7" >2.862</td>
#       <td id="T_09d32_row2_col8" class="data row2 col8" >2.884</td>
#       <td id="T_09d32_row2_col9" class="data row2 col9" >2.937</td>
#       <td id="T_09d32_row2_col10" class="data row2 col10" >3.049</td>
#       <td id="T_09d32_row2_col11" class="data row2 col11" >3.039</td>
#     </tr>
#     <tr>
#       <th id="T_09d32_level0_row3" class="row_heading level0 row3" >Gaussian Process Regression</th>
#       <td id="T_09d32_row3_col0" class="data row3 col0" >2.839</td>
#       <td id="T_09d32_row3_col1" class="data row3 col1" >2.707</td>
#       <td id="T_09d32_row3_col2" class="data row3 col2" >2.694</td>
#       <td id="T_09d32_row3_col3" class="data row3 col3" >2.669</td>
#       <td id="T_09d32_row3_col4" class="data row3 col4" >2.779</td>
#       <td id="T_09d32_row3_col5" class="data row3 col5" >2.803</td>
#       <td id="T_09d32_row3_col6" class="data row3 col6" >2.797</td>
#       <td id="T_09d32_row3_col7" class="data row3 col7" >2.818</td>
#       <td id="T_09d32_row3_col8" class="data row3 col8" >2.848</td>
#       <td id="T_09d32_row3_col9" class="data row3 col9" >2.899</td>
#       <td id="T_09d32_row3_col10" class="data row3 col10" >3.008</td>
#       <td id="T_09d32_row3_col11" class="data row3 col11" >3.009</td>
#     </tr>
#     <tr>
#       <th id="T_09d32_level0_row4" class="row_heading level0 row4" >Random Forest</th>
#       <td id="T_09d32_row4_col0" class="data row4 col0" >2.866</td>
#       <td id="T_09d32_row4_col1" class="data row4 col1" >2.712</td>
#       <td id="T_09d32_row4_col2" class="data row4 col2" >2.997</td>
#       <td id="T_09d32_row4_col3" class="data row4 col3" >2.699</td>
#       <td id="T_09d32_row4_col4" class="data row4 col4" >2.770</td>
#       <td id="T_09d32_row4_col5" class="data row4 col5" >2.801</td>
#       <td id="T_09d32_row4_col6" class="data row4 col6" >2.818</td>
#       <td id="T_09d32_row4_col7" class="data row4 col7" >2.856</td>
#       <td id="T_09d32_row4_col8" class="data row4 col8" >2.863</td>
#       <td id="T_09d32_row4_col9" class="data row4 col9" >2.911</td>
#       <td id="T_09d32_row4_col10" class="data row4 col10" >3.007</td>
#       <td id="T_09d32_row4_col11" class="data row4 col11" >3.011</td>
#     </tr>
#     <tr>
#       <th id="T_09d32_level0_row5" class="row_heading level0 row5" >XGBoost</th>
#       <td id="T_09d32_row5_col0" class="data row5 col0" >3.207</td>
#       <td id="T_09d32_row5_col1" class="data row5 col1" >2.774</td>
#       <td id="T_09d32_row5_col2" class="data row5 col2" >2.861</td>
#       <td id="T_09d32_row5_col3" class="data row5 col3" >2.689</td>
#       <td id="T_09d32_row5_col4" class="data row5 col4" >2.706</td

# %%
idx = [x["name"] for x in model_info_list]
# fit time
result_df.pivot_table(index="name", columns="solver_number", values="fit_time", aggfunc="mean").loc[idx].style.background_gradient(cmap="coolwarm", axis=None).format(precision=2)
# Out:
# <style type="text/css">
# #T_df7d6_row0_col0, #T_df7d6_row0_col1, #T_df7d6_row0_col2, #T_df7d6_row0_col3, #T_df7d6_row0_col4, #T_df7d6_row0_col5, #T_df7d6_row0_col6, #T_df7d6_row0_col7, #T_df7d6_row0_col8, #T_df7d6_row0_col9, #T_df7d6_row0_col10, #T_df7d6_row0_col11, #T_df7d6_row1_col0, #T_df7d6_row1_col1, #T_df7d6_row1_col2, #T_df7d6_row1_col3, #T_df7d6_row2_col0, #T_df7d6_row2_col1, #T_df7d6_row2_col2, #T_df7d6_row2_col3, #T_df7d6_row2_col4, #T_df7d6_row2_col5, #T_df7d6_row2_col6, #T_df7d6_row2_col7, #T_df7d6_row2_col8, #T_df7d6_row3_col0, #T_df7d6_row3_col1, #T_df7d6_row3_col2, #T_df7d6_row4_col0, #T_df7d6_row4_col1, #T_df7d6_row6_col0, #T_df7d6_row6_col1, #T_df7d6_row6_col2, #T_df7d6_row6_col3, #T_df7d6_row6_col4, #T_df7d6_row6_col5, #T_df7d6_row6_col6, #T_df7d6_row6_col7, #T_df7d6_row6_col8, #T_df7d6_row6_col9, #T_df7d6_row6_col10, #T_df7d6_row6_col11, #T_df7d6_row7_col0, #T_df7d6_row7_col1, #T_df7d6_row7_col2, #T_df7d6_row7_col3, #T_df7d6_row7_col4, #T_df7d6_row7_col5, #T_df7d6_row8_col0, #T_df7d6_row8_col1, #T_df7d6_row8_col2, #T_df7d6_row8_col3, #T_df7d6_row8_col4, #T_df7d6_row8_col5, #T_df7d6_row8_col6, #T_df7d6_row8_col7, #T_df7d6_row8_col8, #T_df7d6_row8_col9, #T_df7d6_row8_col10, #T_df7d6_row8_col11, #T_df7d6_row9_col0, #T_df7d6_row9_col1, #T_df7d6_row9_col2, #T_df7d6_row9_col3, #T_df7d6_row9_col4, #T_df7d6_row10_col0, #T_df7d6_row10_col1, #T_df7d6_row10_col2, #T_df7d6_row10_col3, #T_df7d6_row10_col4, #T_df7d6_row10_col5, #T_df7d6_row13_col0, #T_df7d6_row13_col1, #T_df7d6_row13_col2, #T_df7d6_row14_col0, #T_df7d6_row14_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_df7d6_row1_col4, #T_df7d6_row2_col9, #T_df7d6_row3_col3, #T_df7d6_row4_col2, #T_df7d6_row4_col3, #T_df7d6_row4_col4, #T_df7d6_row7_col6, #T_df7d6_row7_col7, #T_df7d6_row9_col5, #T_df7d6_row10_col6, #T_df7d6_row10_col7, #T_df7d6_row10_col8, #T_df7d6_row12_col0, #T_df7d6_row12_col1, #T_df7d6_row12_col2, #T_df7d6_row12_col3, #T_df7d6_row12_col4, #T_df7d6_row12_col5, #T_df7d6_row12_col6, #T_df7d6_row13_col3, #T_df7d6_row14_col2, #T_df7d6_row14_col3 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_df7d6_row1_col5, #T_df7d6_row2_col10, #T_df7d6_row3_col4, #T_df7d6_row4_col5, #T_df7d6_row7_col8, #T_df7d6_row9_col6, #T_df7d6_row9_col7, #T_df7d6_row10_col9, #T_df7d6_row10_col10, #T_df7d6_row12_col7, #T_df7d6_row12_col8, #T_df7d6_row12_col9, #T_df7d6_row12_col10, #T_df7d6_row13_col4, #T_df7d6_row14_col4 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_df7d6_row1_col6, #T_df7d6_row3_col5, #T_df7d6_row4_col6, #T_df7d6_row7_col9, #T_df7d6_row9_col8, #T_df7d6_row12_col11, #T_df7d6_row14_col5, #T_df7d6_row17_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_df7d6_row1_col7, #T_df7d6_row3_col6, #T_df7d6_row7_col10, #T_df7d6_row9_col9, #T_df7d6_row10_col11, #T_df7d6_row13_col5, #T_df7d6_row17_col1 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_df7d6_row1_col8, #T_df7d6_row2_col11, #T_df7d6_row5_col2, #T_df7d6_row5_col4, #T_df7d6_row5_col5, #T_df7d6_row11_col7, #T_df7d6_row11_col8 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_df7d6_row1_col9, #T_df7d6_row13_col7, #T_df7d6_row15_col6, #T_df7d6_row16_col6 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_df7d6_row1_col10 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_df7d6_row1_col11 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_df7d6_row3_col7, #T_df7d6_row5_col0, #T_df7d6_row5_col1, #T_df7d6_row5_col3, #T_df7d6_row9_col10, #T_df7d6_row11_col0, #T_df7d6_row11_col4, #T_df7d6_row11_col5, #T_df7d6_row11_col6, #T_df7d6_row14_col6 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_df7d6_row3_col8, #T_df7d6_row4_col9, #T_df7d6_row5_col9, #T_df7d6_row7_col11, #T_df7d6_row15_col1, #T_df7d6_row15_col2, #T_df7d6_row15_col3, #T_df7d6_row16_col3, #T_df7d6_row16_col4 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_df7d6_row3_col9 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_df7d6_row3_col10 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_df7d6_row3_col11 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_df7d6_row4_col7, #T_df7d6_row11_col1, #T_df7d6_row11_col2, #T_df7d6_row11_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_df7d6_row4_col8, #T_df7d6_row5_col6, #T_df7d6_row11_col9, #T_df7d6_row13_col6, #T_df7d6_row17_col2 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_df7d6_row4_col10, #T_df7d6_row9_col11, #T_df7d6_row15_col9 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_df7d6_row4_col11 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_df7d6_row5_col7, #T_df7d6_row11_col10, #T_df7d6_row11_col11, #T_df7d6_row16_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_df7d6_row5_col8, #T_df7d6_row14_col7, #T_df7d6_row15_col0, #T_df7d6_row16_col1, #T_df7d6_row16_col2, #T_df7d6_row17_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_df7d6_row5_col10, #T_df7d6_row15_col4, #T_df7d6_row15_col5 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_df7d6_row5_col11, #T_df7d6_row16_col5 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_df7d6_row13_col8 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_df7d6_row13_col9 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_df7d6_row13_col10 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_df7d6_row13_col11 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_df7d6_row14_col8 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_df7d6_row14_col9 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_df7d6_row14_col10 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_df7d6_row14_col11 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_df7d6_row15_col7, #T_df7d6_row17_col4 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_df7d6_row15_col8, #T_df7d6_row16_col7 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_df7d6_row15_col10, #T_df7d6_row16_col8 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_df7d6_row15_col11 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_df7d6_row16_col9, #T_df7d6_row17_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_df7d6_row16_col10 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_df7d6_row16_col11 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_df7d6_row17_col6 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_df7d6_row17_col7 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_df7d6_row17_col8 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_df7d6_row17_col9 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_df7d6_row17_col10 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_df7d6_row17_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_df7d6">
#   <thead>
#     <tr>
#       <th class="index_name level0" >solver_number</th>
#       <th id="T_df7d6_level0_col0" class="col_heading level0 col0" >5</th>
#       <th id="T_df7d6_level0_col1" class="col_heading level0 col1" >10</th>
#       <th id="T_df7d6_level0_col2" class="col_heading level0 col2" >15</th>
#       <th id="T_df7d6_level0_col3" class="col_heading level0 col3" >20</th>
#       <th id="T_df7d6_level0_col4" class="col_heading level0 col4" >30</th>
#       <th id="T_df7d6_level0_col5" class="col_heading level0 col5" >50</th>
#       <th id="T_df7d6_level0_col6" class="col_heading level0 col6" >70</th>
#       <th id="T_df7d6_level0_col7" class="col_heading level0 col7" >100</th>
#       <th id="T_df7d6_level0_col8" class="col_heading level0 col8" >150</th>
#       <th id="T_df7d6_level0_col9" class="col_heading level0 col9" >200</th>
#       <th id="T_df7d6_level0_col10" class="col_heading level0 col10" >300</th>
#       <th id="T_df7d6_level0_col11" class="col_heading level0 col11" >500</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&

# %%
# predict time
result_df.pivot_table(index="name", columns="solver_number", values="predict_time", aggfunc="mean").loc[idx].style.background_gradient(cmap="coolwarm", axis=None).format(precision=2)
# Out:
# <style type="text/css">
# #T_0163f_row0_col0, #T_0163f_row0_col1, #T_0163f_row0_col2, #T_0163f_row0_col3, #T_0163f_row0_col4, #T_0163f_row0_col5, #T_0163f_row0_col6, #T_0163f_row0_col7, #T_0163f_row0_col8, #T_0163f_row0_col9, #T_0163f_row0_col10, #T_0163f_row0_col11, #T_0163f_row1_col0, #T_0163f_row1_col1, #T_0163f_row1_col2, #T_0163f_row1_col3, #T_0163f_row1_col4, #T_0163f_row1_col5, #T_0163f_row1_col6, #T_0163f_row1_col7, #T_0163f_row2_col0, #T_0163f_row2_col1, #T_0163f_row2_col2, #T_0163f_row2_col3, #T_0163f_row2_col4, #T_0163f_row2_col5, #T_0163f_row7_col6, #T_0163f_row7_col7, #T_0163f_row8_col0, #T_0163f_row8_col1, #T_0163f_row8_col2, #T_0163f_row8_col3, #T_0163f_row8_col4, #T_0163f_row8_col5, #T_0163f_row8_col6, #T_0163f_row8_col7, #T_0163f_row12_col1, #T_0163f_row12_col5, #T_0163f_row14_col0, #T_0163f_row14_col1, #T_0163f_row14_col2, #T_0163f_row14_col3, #T_0163f_row14_col4, #T_0163f_row14_col5, #T_0163f_row17_col0, #T_0163f_row17_col1, #T_0163f_row17_col2, #T_0163f_row17_col3, #T_0163f_row17_col4, #T_0163f_row17_col5, #T_0163f_row17_col6, #T_0163f_row17_col7, #T_0163f_row17_col8, #T_0163f_row17_col9, #T_0163f_row17_col10, #T_0163f_row17_col11 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_0163f_row1_col8, #T_0163f_row1_col9, #T_0163f_row1_col10, #T_0163f_row2_col6, #T_0163f_row2_col7, #T_0163f_row3_col1, #T_0163f_row6_col6, #T_0163f_row6_col10, #T_0163f_row6_col11, #T_0163f_row7_col0, #T_0163f_row7_col5, #T_0163f_row7_col8, #T_0163f_row7_col9, #T_0163f_row7_col10, #T_0163f_row8_col8, #T_0163f_row12_col6, #T_0163f_row12_col7, #T_0163f_row14_col6, #T_0163f_row14_col7 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_0163f_row1_col11, #T_0163f_row2_col8, #T_0163f_row3_col0, #T_0163f_row3_col2, #T_0163f_row4_col0, #T_0163f_row4_col1, #T_0163f_row4_col2, #T_0163f_row4_col3, #T_0163f_row4_col4, #T_0163f_row4_col5, #T_0163f_row4_col6, #T_0163f_row5_col3, #T_0163f_row5_col4, #T_0163f_row6_col9, #T_0163f_row7_col11, #T_0163f_row9_col2, #T_0163f_row9_col3, #T_0163f_row9_col4, #T_0163f_row10_col0, #T_0163f_row10_col1, #T_0163f_row10_col2, #T_0163f_row10_col3, #T_0163f_row10_col4, #T_0163f_row10_col5, #T_0163f_row10_col6, #T_0163f_row10_col7, #T_0163f_row10_col8, #T_0163f_row10_col9, #T_0163f_row11_col4, #T_0163f_row12_col0, #T_0163f_row13_col0, #T_0163f_row13_col2, #T_0163f_row15_col2, #T_0163f_row15_col7, #T_0163f_row16_col0, #T_0163f_row16_col1, #T_0163f_row16_col2, #T_0163f_row16_col3, #T_0163f_row16_col4, #T_0163f_row16_col5, #T_0163f_row16_col6, #T_0163f_row16_col7 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_0163f_row2_col9, #T_0163f_row3_col4, #T_0163f_row3_col7, #T_0163f_row4_col11, #T_0163f_row5_col2, #T_0163f_row5_col5, #T_0163f_row5_col6, #T_0163f_row5_col7, #T_0163f_row10_col11, #T_0163f_row13_col5, #T_0163f_row15_col3, #T_0163f_row15_col8, #T_0163f_row16_col10, #T_0163f_row16_col11 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_0163f_row2_col10, #T_0163f_row3_col8, #T_0163f_row8_col11 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_0163f_row2_col11, #T_0163f_row9_col11 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_0163f_row3_col3, #T_0163f_row3_col6, #T_0163f_row4_col7, #T_0163f_row4_col8, #T_0163f_row4_col9, #T_0163f_row4_col10, #T_0163f_row5_col0, #T_0163f_row5_col1, #T_0163f_row5_col8, #T_0163f_row5_col10, #T_0163f_row6_col1, #T_0163f_row6_col7, #T_0163f_row8_col10, #T_0163f_row9_col5, #T_0163f_row9_col8, #T_0163f_row10_col10, #T_0163f_row11_col0, #T_0163f_row11_col1, #T_0163f_row11_col2, #T_0163f_row11_col5, #T_0163f_row11_col6, #T_0163f_row11_col7, #T_0163f_row12_col9, #T_0163f_row13_col3, #T_0163f_row13_col4, #T_0163f_row14_col9, #T_0163f_row15_col4, #T_0163f_row15_col5, #T_0163f_row15_col9, #T_0163f_row16_col8, #T_0163f_row16_col9 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_0163f_row3_col5, #T_0163f_row6_col0, #T_0163f_row6_col2, #T_0163f_row6_col3, #T_0163f_row6_col4, #T_0163f_row6_col5, #T_0163f_row6_col8, #T_0163f_row7_col1, #T_0163f_row7_col2, #T_0163f_row7_col3, #T_0163f_row7_col4, #T_0163f_row8_col9, #T_0163f_row9_col0, #T_0163f_row9_col1, #T_0163f_row12_col2, #T_0163f_row12_col3, #T_0163f_row12_col4, #T_0163f_row12_col8, #T_0163f_row13_col1, #T_0163f_row14_col8 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_0163f_row3_col9, #T_0163f_row13_col7, #T_0163f_row15_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_0163f_row3_col10 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_0163f_row3_col11 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_0163f_row5_col9, #T_0163f_row9_col7, #T_0163f_row9_col9, #T_0163f_row11_col9, #T_0163f_row12_col10 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_0163f_row5_col11, #T_0163f_row9_col6, #T_0163f_row11_col3, #T_0163f_row11_col10, #T_0163f_row11_col11, #T_0163f_row15_col6, #T_0163f_row15_col10 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_0163f_row9_col10 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_0163f_row11_col8, #T_0163f_row13_col6, #T_0163f_row14_col10, #T_0163f_row15_col11 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_0163f_row12_col11 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_0163f_row13_col8 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_0163f_row13_col9 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_0163f_row13_col10 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_0163f_row13_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0163f_row14_col11 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_0163f_row15_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0163f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >solver_number</th>
#       <th id="T_0163f_level0_col0" class="col_heading level0 col0" >5</th>
#       <th id="T_0163f_level0_col1" class="col_heading level0 col1" >10</th>
#       <th id="T_0163f_level0_col2" class="col_heading level0 col2" >15</th>
#       <th id="T_0163f_level0_col3" class="col_heading level0 col3" >20</th>
#       <th id="T_0163f_level0_col4" class="col_heading level0 col4" >30</th>
#       <th id="T_0163f_level0_col5" class="col_heading level0 col5" >50</th>
#       <th id="T_0163f_level0_col6" class="col_heading level0 col6" >70</th>
#       <th id="T_0163f_level0_col7" class="col_heading level0 col7" >100</th>
#       <th id="T_0163f_level0_col8" class="col_heading level0 col8" >150</th>
#       <th id="T_0163f_level0_col9" class="col_heading level0 col9" >200</th>
#       <th id="T_0163f_level0_col10" class="col_heading level0 col10" >300</th>
#       <th id="T_0163f_level0_col11" class="col_heading level0 col11" >500</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0163f_level0_row0" class="row_heading level0 row0" >Ridge Regression</th>
#       <td id="T_0163f_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_0163f_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_0163f_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_0163f_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_0163f_row0_col4" class="data row0 col4" >0.00</td>
#       <td id="T_0163f_row0_col5" class="data row0 col5" >0.00</td>
#       <td id="T_0163f_row0_col6" class="data row0 col6" >0.00</td>
#       <td id="T_0163f_row0_col7" class="data row0 col7" >0.00</td>
#       <td id="T_0163f_row0_col8" class="data row0 col8" >0.00</td>
#       <td id="T_0163f_row0_col9" class="data row0 col9" >0.00</td>
#       <td id="T_0163f_row0_
